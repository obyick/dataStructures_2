# %% [markdown]
# # Prerequisite

# %% [markdown]
# ### Importing the utility functions from the 'utils' module

# %%
import utils

# %% [markdown]
# ### Formatting Species Names

# %%
dactylorhiza_sambucina = "Dactylorhiza_Sambucina".title()   # https://en.wikipedia.org/wiki/dactylorhiza_sambucina
rinorea_niccolifera = "Rinorea_Niccolifera".title()         # https://en.wikipedia.org/wiki/rinorea_niccolifera
welwitschia_mirabilis = "Welwitschia_Mirabilis".title()     # https://en.wikipedia.org/wiki/welwitschia_mirabilis

# %% [markdown]
# ### Dactylorhiza sambucina

# %% [markdown]
# #### Generating `Dactylorhiza Sambucina` networks and preprocessed data

# %%
ds_network, ds_preprocess, ds_gsub = utils.network_gen(utils.stops(dactylorhiza_sambucina), dactylorhiza_sambucina) # Generate original, preprocessed, and subgraph networks for Dactylorhiza Sambucina
# Out:
# c:\Users\mathe\AppData\Local\Programs\Python\Python312\Lib\site-packages\wikipedia\wikipedia.py:389: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 389 of the file c:\Users\mathe\AppData\Local\Programs\Python\Python312\Lib\site-packages\wikipedia\wikipedia.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   lis = BeautifulSoup(html).find_all('li')
# Dactylorhiza_Sambucina - Execution Time: 186.7698290348053
# ...

# %% [markdown]
# #### Summarizing the `Dactylorhiza Sambucina` network data and preprocessed results

# %%
utils.summarize(dactylorhiza_sambucina, ds_network, ds_preprocess, ds_gsub) # Summarise network data for Dactylorhiza Sambucina
# Out:
# Dactylorhiza_Sambucina
#
# Original Nodes: 12658
# Original Edges: 16529
#
# Preprocess Nodes: 12567
# Nodes removed from original: 0.72%
# Preprocess Edges: 16472
# Edges removed from original: 0.34%
# Edges per nodes: 1.01
#
# Final Nodes: 2019
# Nodes removed from preprocess: 83.93%
# Final Edges: 5924
# Edges removed from preprocess: 64.04%
# Edges per nodes: 6.22

# %% [markdown]
# ### Rinorea Niccolifera

# %% [markdown]
# #### Generating `Rinorea Niccolifera` networks and preprocessed data

# %%
rn_network, rn_preprocess, rn_gsub = utils.network_gen(utils.stops(rinorea_niccolifera), rinorea_niccolifera) # Generate original, preprocessed, and subgraph networks for Rinorea Niccolifera
# Out:
# c:\Users\mathe\AppData\Local\Programs\Python\Python312\Lib\site-packages\wikipedia\wikipedia.py:389: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 389 of the file c:\Users\mathe\AppData\Local\Programs\Python\Python312\Lib\site-packages\wikipedia\wikipedia.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   lis = BeautifulSoup(html).find_all('li')
# Rinorea_Niccolifera - Execution Time: 95.15856409072876
# ...

# %% [markdown]
# #### Summarizing the `Rinorea Niccolifera` network data and preprocessed results

# %%
utils.summarize(rinorea_niccolifera, rn_network, rn_preprocess, rn_gsub) # Summarise network data for Rinorea Niccolifera
# Out:
# Rinorea_Niccolifera
#
# Original Nodes: 3175
# Original Edges: 4568
#
# Preprocess Nodes: 3154
# Nodes removed from original: 0.66%
# Preprocess Edges: 4550
# Edges removed from original: 0.39%
# Edges per nodes: 1.01
#
# Final Nodes: 748
# Nodes removed from preprocess: 76.28%
# Final Edges: 2144
# Edges removed from preprocess: 52.88%
# Edges per nodes: 4.22

# %% [markdown]
# ### Welwitschia Mirabilis

# %% [markdown]
# #### Generating `Welwitschia Mirabilis` networks and preprocessed data

# %%
wm_network, wm_preprocess, wm_gsub = utils.network_gen(utils.stops(welwitschia_mirabilis), welwitschia_mirabilis) # Generate original, preprocessed, and subgraph networks for Welwitschia Mirabilis
# Out:
# c:\Users\mathe\AppData\Local\Programs\Python\Python312\Lib\site-packages\wikipedia\wikipedia.py:389: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 389 of the file c:\Users\mathe\AppData\Local\Programs\Python\Python312\Lib\site-packages\wikipedia\wikipedia.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   lis = BeautifulSoup(html).find_all('li')
# Welwitschia_Mirabilis - Execution Time: 291.61055874824524
# ...

# %% [markdown]
# #### Summarizing the `Welwitschia Mirabilis` network data and preprocessed results

# %%
utils.summarize(welwitschia_mirabilis, wm_network, wm_preprocess, wm_gsub) # Summarise network data for Welwitschia Mirabilis
# Out:
# Welwitschia_Mirabilis
#
# Original Nodes: 16804
# Original Edges: 24966
#
# Preprocess Nodes: 16710
# Nodes removed from original: 0.56%
# Preprocess Edges: 24893
# Edges removed from original: 0.29%
# Edges per nodes: 1.01
#
# Final Nodes: 3739
# Nodes removed from preprocess: 77.62%
# Final Edges: 11922
# Edges removed from preprocess: 52.11%
# Edges per nodes: 4.47
